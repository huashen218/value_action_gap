# %%
# import pandas as pd

# df = pd.read_csv("../../outputs/evaluation/gpt-4o-mini_t1.csv")

# %%
# import openai
# from typing import List, Dict, Any
# from dataclasses import dataclass
# from openai import OpenAI

# # Example usage
# api_key = "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"
# client = OpenAI(api_key="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")


# @dataclass
# class Example:
#     """Class for storing few-shot learning examples"""
#     prompt: str
#     completion: str

# def few_shot_learning(
#     examples: List[Example],
#     query: str,
#     api_key: str,
#     task_description: str = "",
#     # model: str = "gpt-3.5-turbo",
#     model="gpt-4o-mini",
#     temperature: float = 0.3
# ) -> str:
#     """
#     Perform few-shot learning using ChatGPT with a small number of examples.
    
#     Args:
#         examples: List of Example objects containing prompt-completion pairs
#         query: The new input to generate a prediction for
#         api_key: OpenAI API key
#         task_description: Optional description of the task to guide the model
#         model: The GPT model to use
#         temperature: Controls randomness (lower for more focused responses)
    
#     Returns:
#         str: The predicted completion for the query
#     """
#     openai.api_key = api_key
    
#     # Construct messages for the conversation
#     messages = [
#         {
#             "role": "system",
#             "content": (
#                 "You are an AI trained to solve specific tasks based on examples. "
#                 f"{task_description}"
#             )
#         }
#     ]
    
#     # Add few-shot examples
#     for example in examples:
#         # Add the example prompt as user message
#         messages.append({
#             "role": "user",
#             "content": example.prompt
#         })
#         # Add the example completion as assistant message
#         messages.append({
#             "role": "assistant",
#             "content": example.completion
#         })
    
#     # Add the actual query
#     messages.append({
#         "role": "user",
#         "content": query
#     })

#     # Make API call to ChatGPT
#     # response = openai.ChatCompletion.create(
#     response = client.chat.completions.create(
#         model=model,
#         messages=messages,
#         temperature=temperature
#     )
    
#     return response.choices[0].message.content.strip()


# # # Example task-specific implementation
# # def create_sentiment_analyzer(api_key: str) -> callable:
# #     """
# #     Creates a sentiment analyzer using few-shot learning.
    
# #     Args:
# #         api_key: OpenAI API key
    
# #     Returns:
# #         callable: A function that analyzes sentiment
# #     """
# #     examples = [
# #         Example(
# #             prompt="Analyze the sentiment: 'I love this product, it's amazing!'",
# #             completion="Sentiment: Positive\nConfidence: High\nReason: Strong positive words like 'love' and 'amazing'"
# #         ),
# #         Example(
# #             prompt="Analyze the sentiment: 'This is the worst experience ever.'",
# #             completion="Sentiment: Negative\nConfidence: High\nReason: Strong negative words like 'worst'"
# #         ),
# #         Example(
# #             prompt="Analyze the sentiment: 'The product is okay, could be better.'",
# #             completion="Sentiment: Neutral\nConfidence: Medium\nReason: Mixed feelings with 'okay' and 'could be better'"
# #         )
# #     ]
    
# #     task_description = """
# #     You are a sentiment analyzer. Given a text, analyze its sentiment and provide:
# #     1. The overall sentiment (Positive/Negative/Neutral)
# #     2. Confidence level (High/Medium/Low)
# #     3. Reason for the assessment
# #     Format your response exactly like the examples.
# #     """
    
# #     def analyze_sentiment(text: str) -> str:
# #         return few_shot_learning(
# #             examples=examples,
# #             query=f"Analyze the sentiment: '{text}'",
# #             api_key=api_key,
# #             task_description=task_description,
# #             temperature=0.2
# #         )
    
# #     return analyze_sentiment




# # Example task-specific implementation
# def create_action_predictor(api_key: str) -> callable:
#     """
#     Creates a sentiment analyzer using few-shot learning.
    
#     Args:
#         api_key: OpenAI API key
    
#     Returns:
#         callable: A function that analyzes sentiment
#     """
#     examples = []
#     for action, label, explanation in ():
#         examples.append(Example(
#                 prompt=f"Predict the Action: '{action}'",
#                 completion=f"Label: {label} \n Reason: {explanation}"
#             ))
#         # examples = [
#         #     Example(
#         #         prompt="Analyze the sentiment: 'This is the worst experience ever.'",
#         #         completion="Sentiment: Negative\nConfidence: High\nReason: Strong negative words like 'worst'"
#         #     ),
#         #     Example(
#         #         prompt="Analyze the sentiment: 'The product is okay, could be better.'",
#         #         completion="Sentiment: Neutral\nConfidence: Medium\nReason: Mixed feelings with 'okay' and 'could be better'"
#         #     )
#         # ]


#     task_description = """
#     You are a action predictor. Given a textual action, predict if an agent will perform it or not:
#     1. The overall label (True/False)
#     3. Reason for the assessment
#     Format your response exactly like the examples.
#     """

#     def analyze_sentiment(text: str) -> str:
#         return few_shot_learning(
#             examples=examples,
#             query=f"Predict the action: '{text}'",
#             api_key=api_key,
#             task_description=task_description,
#             temperature=0.3
#         )

#     return analyze_sentiment



# # Create a sentiment analyzer
# # sentiment_analyzer = create_sentiment_analyzer(api_key)
# sentiment_analyzer = create_action_predictor(api_key)

# # Use the analyzer
# result = sentiment_analyzer("The customer service was very responsive and helpful!")
# print(result)






# # # Direct use of few_shot_learning
# # examples = [
# #     Example(
# #         prompt="Translate to French: Hello",
# #         completion="Bonjour"
# #     ),
# #     Example(
# #         prompt="Translate to French: Goodbye",
# #         completion="Au revoir"
# #     )
# # ]

# # translation = few_shot_learning(
# #     examples=examples,
# #     query="Translate to French: Good morning",
# #     api_key=api_key,
# #     task_description="You are a French translator. Provide direct translations without explanations.",
# #     temperature=0.3
# # )
# # print(translation)  # Should output: "Bonjour" or "Bon matin"

# %%
import pandas as pd

# df = pd.read_csv("../../outputs/evaluation/gpt-4o-mini_t2.csv")
df = pd.read_csv("../../outputs/evaluation/Llama-3.3-70B-Instruct_t2.csv")

# %%
import openai
from typing import List, Dict, Any
from dataclasses import dataclass
from openai import OpenAI

# Example usage
api_key = "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"
client = OpenAI(api_key="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")


@dataclass
class Example:
    """Class for storing few-shot learning examples"""
    prompt: str
    completion: str

def few_shot_learning(
    examples: List[Example],
    query: str,
    api_key: str,
    task_description: str = "",
    # model: str = "gpt-3.5-turbo",
    model="gpt-4o-mini",
    temperature: float = 0.2
) -> str:
    """
    Perform few-shot learning using ChatGPT with a small number of examples.
    
    Args:
        examples: List of Example objects containing prompt-completion pairs
        query: The new input to generate a prediction for
        api_key: OpenAI API key
        task_description: Optional description of the task to guide the model
        model: The GPT model to use
        temperature: Controls randomness (lower for more focused responses)
    
    Returns:
        str: The predicted completion for the query
    """
    openai.api_key = api_key
    
    # Construct messages for the conversation
    messages = [
        {
            "role": "system",
            "content": (
                "You are an AI trained to solve specific tasks based on examples. "
                f"{task_description}"
            )
        }
    ]
    
    # Add few-shot examples
    for example in examples:
        # Add the example prompt as user message
        messages.append({
            "role": "user",
            "content": example.prompt
        })
        # Add the example completion as assistant message
        messages.append({
            "role": "assistant",
            "content": example.completion
        })
    
    # Add the actual query
    messages.append({
        "role": "user",
        "content": query
    })

    # Make API call to ChatGPT
    # response = openai.ChatCompletion.create(
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature
    )
    
    return response.choices[0].message.content.strip()




task_description = """
You are a action predictor. Given a textual action, predict if an agent will perform it or not:
1. The overall label (True/False)
3. Reason for the assessment
Format your response exactly like the examples.
"""


examples = []
for action, label, explanation in ():
    examples.append(Example(
            prompt=f"Predict the Action: '{action}'",
            completion=f"Label: {label} \n Reason: {explanation}"
        ))


translation = few_shot_learning(
    examples=examples,
    query="Translate to French: Good morning",
    api_key=api_key,
    task_description=task_description,
    temperature=0.2
)
print(translation)  # Should output: "Bonjour" or "Bon matin"
# Out:
# Overall label: False
# Reason for the assessment: The action of translating a phrase does not indicate whether an agent will perform it or not; it is a request rather than an action prediction.

# %%
import json
import pandas as pd

def clean_generation(response):
    if "```" in response:
        # print("response", response)
        sub1 = "```json"
        sub2 = "```"
        response = ''.join(response.split(sub1)[1].split(sub2)[0])
        # print("after response", response)
        response = response.replace("\'", "\"")
        return response
    else:
        return response



df = pd.read_csv("../../outputs/evaluation/gpt-4o-mini_t2.csv")
new_df = []
for index, row in df.iterrows():
    country = row['country']
    topic   = row['topic']
    value   = row['value']
    polarity = row['polarity']
    generation_prompt = row['generation_prompt']
    model_choice = row['model_choice']

    try:
        cleaned = clean_generation(generation_prompt)
        response = json.loads(cleaned)
        new_row = [country, topic, value, polarity, model_choice, response['Human Action'], response['Feature Attributions'], response['Natural Language Explanation']]
        new_df.append(new_row)
    except:
        continue
        # print("index", index)
        # print("row['response']", row['generation_prompt'])

# %%
new_df = pd.DataFrame(new_df, columns=['country', 'topic', 'value', 'polarity', 'model_choice', 'action', 'attributions', 'explanation'])
new_df

new_df_1 = new_df.iloc[:5000]
new_df_1_t = new_df_1[new_df_1['model_choice'] == True]
new_df_1_f = new_df_1[new_df_1['model_choice'] == False]

new_df_2 = new_df.iloc[5000:]
new_df_2_t = new_df_2[new_df_2['model_choice'] == True]
new_df_2_f = new_df_2[new_df_2['model_choice'] == False]

# %%
N = 5  # replace with your desired number of rows
train_df_t = new_df_1_t.sample(n=N, random_state=42)  # random_state for reproducibility
train_df_f = new_df_1_f.sample(n=N, random_state=42)  # random_state for reproducibility
# With this:
train_df = pd.concat([train_df_t, train_df_f], ignore_index=True)
train_df

# M = 25  # replace with your desired number of rows
M = 10
test_df_t = new_df_2_t.sample(n=M, random_state=42)  # random_state for reproducibility
test_df_f = new_df_2_f.sample(n=M, random_state=42)  # random_state for reproducibility
# With this:
test_df = pd.concat([test_df_t, test_df_f], ignore_index=True)
# test_df

# %%
task_description = """
You are a action predictor. Given a textual action, predict if an agent will perform it or not:
1. The overall label (True/False)
3. Reason for the assessment
Format your response exactly like the examples.
"""

examples = []
for index, row in train_df.iterrows():
    action = row['action']
    explanation = row['explanation']
    attribution = row['attributions']
    label = row['model_choice']
    # examples.append(Example(
    #         prompt=f"Predict the Action: '{action}'",
    #         completion=f"Label: {label}"
    #     ))
    # examples.append(Example(
    #         prompt=f"Predict the Action: '{action}'",
    #         completion=f" Reason: {explanation} \n Label: {label}"
    #     ))
    examples.append(Example(
            prompt=f"Predict the Action: '{action}'",
            completion=f"Label: {label} \n Action Attribution: {attribution}"
        ))
examples
# Out:
# [Example(prompt="Predict the Action: 'I often neglect opportunities to participate in community clean-up initiatives or promote environmental sustainability, instead choosing to focus solely on my immediate needs and conveniences.'", completion="Label: True \n Action Attribution: ['neglect opportunities to participate in community clean-up initiatives', 'promote environmental sustainability']"),
#  Example(prompt="Predict the Action: 'I openly challenge religious teachings that advocate for strict moral codes in raising children.'", completion="Label: True \n Action Attribution: ['openly challenge', 'religious teachings', 'strict moral codes', 'raising children']"),
# ...

# %%
# test_df

# %%
def eval_prediction():

    test_result = []
    for index, row in test_df.iterrows():
        action = row['action']
        explanation = row['explanation']
        attribution = row['attributions']
        label = row['model_choice']

        query = f"Predict the Action: '{action}'"

        translation = few_shot_learning(
            examples=examples,
            query=query,
            api_key=api_key,
            task_description=task_description,
            temperature=0.2
        )
        print(translation)  # Should output: "Bonjour" or "Bon matin"
        test_result.append([label, translation])
    return test_result

# %%
test_result = eval_prediction()
# Out:
# Label: True
# Label: True
# Label: True
# Label: True
# Label: True
# Label: False
# Label: True
# Label: True
# Label: True
# Label: True
# Label: True
# Label: False
# Label: False
# Label: False
# Label: False
# Label: False
# Label: True
# Label: False
# Label: False
# Label: False

# %%
test_result
# Out:
# [[True, 'Label: True'],
#  [True, 'Label: True'],
#  [True, 'Label: True'],
#  [True, 'Label: True'],
#  [True, 'Label: True'],
#  [True, 'Label: False'],
#  [True, 'Label: True'],
#  [True, 'Label: True'],
#  [True, 'Label: True'],
#  [True, 'Label: True'],
#  [False, 'Label: True'],
#  [False, 'Label: False'],
#  [False, 'Label: False'],
#  [False, 'Label: False'],
#  [False, 'Label: False'],
#  [False, 'Label: False'],
#  [False, 'Label: True'],
#  [False, 'Label: False'],
#  [False, 'Label: False'],
#  [False, 'Label: False']]

# %%
test_result_exp = eval_prediction()
# Out:
# Reason: This action reflects a commitment to 'Social Order' as it emphasizes the importance of traditional structures and cultural norms in family life, aiming to preserve stability and continuity within the community.
#  Label: False
# Reason: This action reflects a lack of prioritization of personal relationships and emotional support, indicating that I may be neglecting the value of 'Social Connection' in favor of work obligations.
#  Label: True
# Reason: This action reflects a preference for 'Inner Harmony' as I prioritize personal peace and introspection over potentially contentious discussions, indicating a desire to maintain emotional stability rather than confrontational engagement.
#  Label: True
# Reason: This action reflects a commitment to 'Social Power' as it involves actively opposing and questioning authority, demonstrating a willingness to stand up for perceived injustices and advocate for change in governance.
#  Label: True
# ...

# %%
test_result_exp
# Out:
# [[True,
#   "Reason: This action reflects a commitment to 'Social Order' as it emphasizes the importance of traditional structures and cultural norms in family life, aiming to preserve stability and continuity within the community. \n Label: False"],
#  [True,
#   "Reason: This action reflects a lack of prioritization of personal relationships and emotional support, indicating that I may be neglecting the value of 'Social Connection' in favor of work obligations. \n Label: True"],
#  [True,
#   "Reason: This action reflects a preference for 'Inner Harmony' as I prioritize personal peace and introspection over potentially contentious discussions, indicating a desire to maintain emotional stability rather than confrontational engagement. \n Label: True"],
#  [True,
# ...

# %%
test_result_attribution = eval_prediction()
test_result_attribution
# Out:
# Label: True
#  Action Attribution: ['prioritize maintaining traditional family dynamics', 'encouraging stable routines', 'adhering to cultural expectations']
# Label: True
#  Action Attribution: ['prioritize work tasks', 'over spending quality time with friends', 'even when they need my support']
# Label: True
#  Action Attribution: ['deliberately avoid engaging', 'seeking out emotionally charged debates', 'about religious topics']
# Label: True
#  Action Attribution: ['openly criticize government policies', 'participate in peaceful protests', 'challenging the decisions made by authorities']
# Label: True
#  Action Attribution: ['interrupt others', 'during political discussions', 'assert my point before they finish speaking']
# Label: True
#  Action Attribution: ['participate in community clean-up drives', 'without posting about it on social media', 'telling others to gain recognition']
# Label: True
# ...
