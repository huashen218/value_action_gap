# %%
import pandas as pd


countries = ["United States", "India", "Pakistan", "Nigeria", "Philippines", "United Kingdom", "Germany", "Uganda", "Canada", "Egypt", "France", "Australia"]


all_data = []
for country in countries:
    path = f'1212_full_value_action_generation_gpt_4o_{country}.csv'
    data = pd.read_csv(path)  
    all_data.append(data)

# %%
new_df = pd.concat(all_data)
new_df.to_csv("1212_full_value_action_generation_gpt_4o.csv")

# %%
new_df
# Out:
#      Unnamed: 0        country                   topic         value  \
# 0             0  United States                Politics  Social Power
# 1             1  United States                Politics  Social Power
# 2             2  United States                Politics    Successful
# 3             3  United States                Politics    Successful
# 4             4  United States                Politics      Pleasure
# ..          ...            ...                     ...           ...
# 215         215      Australia  Health and Health Care        Devout
# 216         216      Australia  Health and Health Care    Politeness
# 217         217      Australia  Health and Health Care    Politeness
# 218         218      Australia  Health and Health Care         Clean
# 219         219      Australia  Health and Health Care         Clean
#
#      polarity                                  generation_prompt
# 0    positive  {\n  "Human Action": "I raise funds and build ...
# 1    negative  {\n  "Human Action": "I actively prioritize co...
# 2    positive  {\n  "Human Action": "I actively participate i...
# 3    negative  {\n  'Human Action': 'I choose not to vote or ...
# 4    positive  ```json\n{\n  "Human Action": "I volunteer my ...
# ..        ...                                                ...
# 215  negative  {\n    "Human Action": "I prioritize evidence-...
# 216  positive  {\n  'Human Action': 'I patiently listen to he...
# 217  negative  ```json\n{\n  "Human Action": "I interrupted t...
# 218  positive  ```json\n{\n  "Human Action": "I always wash m...
# 219  negative  {\n  "Human Action": "I neglect to wash my han...
#
# [2640 rows x 6 columns]
